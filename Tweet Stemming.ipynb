# %%
import re
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import string
import nltk
import warnings 
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %matplotlib inline

# %%
data = pd.read_csv('C:/Users/deepa/Documents/Sem 6/Data Mining and Data Warehousing/Twitter Data New.csv')

# %%
data
# Out:
#        Unnamed: 0            Id Language       User Id  \
# 0               0  1.250000e+18       en  1.461106e+09
# 1               1  1.250000e+18       en  1.230000e+18
# 2               2  1.250000e+18       en  1.040000e+18
# 3               3  1.250000e+18       en  1.949401e+08
# 4               4  1.250000e+18       en  7.627854e+08
# 5               5  1.250000e+18       en  1.013038e+09
# 6               6  1.250000e+18       en  1.020000e+18
# 7               7  1.250000e+18       en  4.415700e+08
# 8               9  1.250000e+18       en  8.920000e+17
# 9              10  1.250000e+18       en  4.518362e+09
# 10             11  1.250000e+18       en  1.140000e+18
# 11             12  1.250000e+18       en  1.130000e+18
# 12             13  1.250000e+18       en  9.650000e+17
# 13             14  1.250000e+18       en  3.189049e+09
# 14             15  1.250000e+18       en  7.590000e+17
# 15             16  1.250000e+18       en  1.220000e+18
# ...

# %%
from nltk import PorterStemmer

tokenized_tweet = data['Filtered Text'].apply(lambda x: x.split())

# %%
ps = PorterStemmer()

tokenized_tweet = tokenized_tweet.apply(lambda x: [ps.stem(i) for i in x])

tokenized_tweet.head()
# Out:
# 0    [cycl, caffein, good, way, preserv, effect, ti...
# 1    [famili, first, coronaviru, respons, act, new,...
# 2                         [follow, peopl, like, tweet]
# 3    [sister, frontlin, covid, postiv, pray, unceas...
# 4                                               [love]
# Name: Filtered Text, dtype: object

# %%
for i in range(len(tokenized_tweet)):
    tokenized_tweet[i] = ' '.join(tokenized_tweet[i])

data['Clean Tweets'] = tokenized_tweet
data.head()
# Out:
#    Unnamed: 0            Id Language       User Id  \
# 0           0  1.250000e+18       en  1.461106e+09
# 1           1  1.250000e+18       en  1.230000e+18
# 2           2  1.250000e+18       en  1.040000e+18
# 3           3  1.250000e+18       en  1.949401e+08
# 4           4  1.250000e+18       en  7.627854e+08
#
#                                       Retweet Status                 Mentions  \
# 0  {'created_at': 'Wed Apr 01 06:25:17 +0000 2020...              safetyth1rd
# 1  {'created_at': 'Wed Apr 01 06:40:24 +0000 2020...             abc13houston
# 2  {'created_at': 'Tue Mar 31 22:12:08 +0000 2020...              playboiwaru
# 3  {'created_at': 'Tue Mar 31 12:10:33 +0000 2020...             FrizzleAnne_
# 4  {'created_at': 'Wed Apr 01 06:35:04 +0000 2020...  Msuppasilt, gulfkanawut
#
#             Hashtags                                               Text  \
# 0  Nootropic, coffee  RT @safetyth1rd: Cycling caffeine is a good wa...
# ...

# %%
df = pd.DataFrame(data)

# %%
df.to_csv('C:/Users/deepa/Documents/Sem 6/Data Mining and Data Warehousing/Preprocessed Twitter Data.csv')
